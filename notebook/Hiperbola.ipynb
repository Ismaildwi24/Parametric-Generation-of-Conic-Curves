# %% [markdown]
# # Program Kurva Hiperbola
#
# # Parametric Generation of Conic Curves
#
# # Deskripsi
# Program ini digunakan untuk membangkitkan kurva hiperbola menggunakan persamaan parametrik serta membandingkan pengaruh nilai Δθ (delta theta) terhadap jumlah titik dan kualitas visualisasi kurva.
#
# # Tujuan
# 1. Membuat kurva hiperbola menggunakan persamaan parametrik (trigonometri secant dan tangent).
# 2. Menampilkan titik-titik pembentuk kedua cabang kurva (kiri dan kanan).
# 3. Membandingkan resolusi kurva berdasarkan nilai Δθ.
# 4. Menunjukkan bahwa semakin kecil Δθ maka semakin banyak titik yang dihasilkan sehingga kurva menjadi lebih halus (smooth).
#
# # Dasar Teori
# Hiperbola merupakan kurva irisan kerucut (Conic Section) yang memiliki eksentrisitas e > 1 dan terdiri dari dua cabang yang terpisah. Pada program ini hiperbola dibangkitkan menggunakan persamaan parametrik:
#
# x = xc ± a · sec(θ)
# y = yc + b · tan(θ)
#
# Keterangan:
# - xc = koordinat x titik pusat (center)
# - yc = koordinat y titik pusat (center)
# - a = semi-sumbu transversal (menentukan jarak titik pusat ke puncak kurva)
# - b = semi-sumbu konjugasi (menentukan bukaan kurva)
# - θ = parameter sudut pembentuk kurva (dalam radian)
# - Δθ = interval perubahan parameter θ
#
# # Pengaruh Delta Theta (Δθ) terhadap Resolusi
# Parameter θ dibangkitkan dari interval mendekati -π/2 sampai π/2. Nilai Δθ menentukan jarak perubahan parameter sudut θ.
#
# Contoh:
# - Δθ = 15° menghasilkan jumlah titik yang lebih sedikit (resolusi rendah/patah-patah).
# - Δθ = 1° menghasilkan jumlah titik yang jauh lebih banyak (resolusi tinggi/halus).
#
# Semakin kecil nilai Δθ maka jumlah titik yang dihasilkan semakin banyak sehingga kedua cabang kurva hiperbola menjadi lebih halus (smooth).
#
# # Algoritma Program
# 1. Menginput nilai xc, yc, a, dan b.
# 2. Menginput nilai Δθ besar dan Δθ kecil.
# 3. Membentuk parameter θ dari rentang -90° hingga 90°.
# 4. Menghitung koordinat x dan y untuk cabang kanan dan cabang kiri menggunakan persamaan parametrik trigonometri.
# 5. Menampilkan tabel perhitungan titik-titik kurva.
# 6. Menggambar kurva hiperbola beserta titik-titiknya.
# 7. Membandingkan hasil resolusi rendah dan resolusi tinggi.
#
# # Kesimpulan
# Kurva hiperbola dapat dibangkitkan menggunakan persamaan parametrik dengan memanfaatkan parameter sudut θ. Nilai Δθ memengaruhi jumlah titik yang dihasilkan. Semakin kecil nilai Δθ maka semakin banyak titik yang terbentuk sehingga visualisasi kedua cabang kurva menjadi lebih halus dan presisi.

# %%
from matplotlib import style
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('dark_background')

def plot_hyperbola():
    print("\n=== GENERATOR KURVA HIPERBOLA ===\n")

    xc = float(input("Masukkan titik pusat X (xc): "))
    yc = float(input("Masukkan titik pusat Y (yc): "))
    a = float(input("Masukkan semi-sumbu transversal (a): "))
    b = float(input("Masukkan semi-sumbu konjugasi (b): "))

    step_low = float(input("Step besar (dalam derajat, contoh 15): "))
    step_high = float(input("Step kecil (dalam derajat, contoh 1): "))

    steps = [step_low, step_high]

    titles = [
        "Resolusi Rendah (Step Besar)",
        "Resolusi Tinggi (Step Kecil)"
    ]

    for col in range(2):
        step_deg = steps[col]

        fig, ax = plt.subplots(figsize=(10, 8))
        fig.suptitle(
            "KURVA HIPERBOLA (e > 1)\n"
            "Perbandingan Resolusi Berdasarkan Delta Theta (θ)",
            fontsize=14,
            color='white'
        )
        
        start_deg = -89.9
        end_deg = 89.9
        theta_deg = np.arange(start_deg, end_deg + (step_deg*0.1), step_deg)
        theta_rad = np.deg2rad(theta_deg)

        x_right = xc + a * (1 / np.cos(theta_rad))
        y_right = yc + b * np.tan(theta_rad)
        
        x_left = xc - a * (1 / np.cos(theta_rad))
        y_left = yc + b * np.tan(theta_rad)

        print("\n" + "=" * 100)

        if col == 0:
            print("RESOLUSI RENDAH")
        else:
            print("RESOLUSI TINGGI")

        print("=" * 100)

        # Proses perhitungan jumlah titik
        range_deg = end_deg - start_deg
        num_points = len(theta_deg)
        print(f"Delta θ      = {step_deg}°")
        print(f"Proses cari jumlah titik: Rentang = {end_deg}° - ({start_deg}°) = {range_deg:.1f}°")
        print(f"Jumlah titik = {range_deg:.1f}° / {step_deg}° ≈ {num_points} (per cabang)")

        # Perhitungan Titik Fokus
        c = np.sqrt(a**2 + b**2)
        print("-" * 100)
        print("PERHITUNGAN TITIK FOKUS")
        print(f"c = √(a² + b²) = √({a}² + {b}²) = √({a**2} + {b**2}) = {c:.2f}")
        print(f"Fokus Kanan (F1) = (xc + c, yc) = ({xc} + {c:.2f}, {yc}) = ({xc + c:.2f}, {yc})")
        print(f"Fokus Kiri (F2)  = (xc - c, yc) = ({xc} - {c:.2f}, {yc}) = ({xc - c:.2f}, {yc})")

        # Perhitungan Asimtot
        print("-" * 100)
        print("PERHITUNGAN ASIMTOT")
        print(f"Persamaan Asimtot 1: y = (b/a)(x - xc) + yc = ({b}/{a})(x - {xc}) + {yc}")
        print(f"Persamaan Asimtot 2: y = -(b/a)(x - xc) + yc = -({b}/{a})(x - {xc}) + {yc}")

        print("-" * 100)
        print(
            f"{'θ (deg)':<10}"
            f"{'Perhitungan X (Kanan)':<30}"
            f"{'X':<15}"
            f"{'Perhitungan Y':<25}"
            f"{'Y':<15}"
        )
        print("-" * 100)

        for i in range(len(theta_deg)):
            calc_x = f"{xc}+{a}*sec({theta_deg[i]:.1f}°)"
            calc_y = f"{yc}+{b}*tan({theta_deg[i]:.1f}°)"

            print(
                f"{theta_deg[i]:<10.1f}"
                f"{calc_x:<30}"
                f"{x_right[i]:<15.2f}"
                f"{calc_y:<25}"
                f"{y_right[i]:<15.2f}"
            )

        ax.plot(x_right, y_right, color='yellow', linewidth=2, marker='o', markersize=5, label='Cabang Kanan')
        ax.scatter(x_right, y_right, color='white', s=25, zorder=3)

        ax.plot(x_left, y_left, color='#00ffcc', linewidth=2, marker='o', markersize=5, label='Cabang Kiri')
        ax.scatter(x_left, y_left, color='white', s=25, zorder=3)

        # Plot Titik Fokus
        f1_x, f1_y = xc + c, yc
        f2_x, f2_y = xc - c, yc
        ax.scatter([f1_x, f2_x], [f1_y, f2_y], color='orange', s=100, zorder=5, marker='X', label='Titik Fokus')
        ax.annotate(f'F1({f1_x:.1f}, {f1_y:.1f})', (f1_x, f1_y), textcoords='offset points', xytext=(5, 5), fontsize=8, color='orange')
        ax.annotate(f'F2({f2_x:.1f}, {f2_y:.1f})', (f2_x, f2_y), textcoords='offset points', xytext=(-35, 5), fontsize=8, color='orange')

        # Plot Asimtot
        x_asymptote = np.array([xc - 15*a, xc + 15*a])
        y_asymp_1 = (b/a) * (x_asymptote - xc) + yc
        y_asymp_2 = -(b/a) * (x_asymptote - xc) + yc
        ax.plot(x_asymptote, y_asymp_1, color='lightgreen', linestyle=':', linewidth=2, label='Asimtot')
        ax.plot(x_asymptote, y_asymp_2, color='lightgreen', linestyle=':', linewidth=2)

        limit_x_label = xc + 15 * a
        limit_y_label = yc + 15 * b
        
        for i in range(len(theta_deg)):
            if abs(x_right[i]) <= limit_x_label and abs(y_right[i]) <= limit_y_label:
                ax.annotate(f'({x_right[i]:.0f},{y_right[i]:.0f})', (x_right[i], y_right[i]),
                            textcoords='offset points', xytext=(5, 5), fontsize=6, color='cyan')
            if abs(x_left[i]) <= limit_x_label and abs(y_left[i]) <= limit_y_label:
                ax.annotate(f'({x_left[i]:.0f},{y_left[i]:.0f})', (x_left[i], y_left[i]),
                            textcoords='offset points', xytext=(5, 5), fontsize=6, color='cyan')

        ax.scatter(xc, yc, color='red', s=150, zorder=10)
        ax.annotate(f'CENTER\n({xc:.2f},{yc:.2f})', xy=(xc, yc), xytext=(xc + a*0.5, yc - b*1.5),
                    fontsize=10, color='red', arrowprops=dict(arrowstyle='->', color='red'))

        ax.axvline(xc, color='cyan', linestyle='--', linewidth=2, label='Sumbu Konjugasi Y')
        ax.axhline(yc, color='magenta', linestyle='--', linewidth=1.5, label='Sumbu Transversal X')

        formula = (
            f"x = {xc} ± {a}·sec(θ)\n"
            f"y = {yc} + {b}·tan(θ)\n"
            f"Asimtot:\ny = ±({b}/{a})(x - {xc}) + {yc}"
        )

        ax.text(0.02, 0.98, formula, transform=ax.transAxes, fontsize=10, color='cyan',
                verticalalignment='top', bbox=dict(facecolor='black', alpha=0.8))

        info = (
            f"Delta θ = {step_deg}°\n"
            f"Jml titik/cabang = {num_points}"
        )

        ax.text(0.02, 0.82, info, transform=ax.transAxes, fontsize=9, color='yellow',
                bbox=dict(facecolor='black', alpha=0.8))

        ax.spines['left'].set_position('zero')
        ax.spines['bottom'].set_position('zero')
        ax.spines['right'].set_color('none')
        ax.spines['top'].set_color('none')
        ax.tick_params(colors='white')
        ax.grid(True, linestyle='--', alpha=0.3)

        ax.set_xlim(xc - 5*a, xc + 5*a)
        ax.set_ylim(yc - 5*b, yc + 5*b)

        ax.set_title(titles[col], fontsize=12, color='white')
        ax.legend(loc='upper right')

        plt.tight_layout()

    plt.show()

plot_hyperbola()
# Out:
# === GENERATOR KURVA HIPERBOLA ===
#
#
# ====================================================================================================
# RESOLUSI RENDAH
# ====================================================================================================
# Delta θ      = 10.0°
# Proses cari jumlah titik: Rentang = 89.9° - (-89.9°) = 179.8°
# Jumlah titik = 179.8° / 10.0° ≈ 19 (per cabang)
# ----------------------------------------------------------------------------------------------------
# PERHITUNGAN TITIK FOKUS
# c = √(a² + b²) = √(5.0² + 5.0²) = √(25.0 + 25.0) = 7.07
# Fokus Kanan (F1) = (xc + c, yc) = (15.0 + 7.07, 15.0) = (22.07, 15.0)
# Fokus Kiri (F2)  = (xc - c, yc) = (15.0 - 7.07, 15.0) = (7.93, 15.0)
# ----------------------------------------------------------------------------------------------------
# PERHITUNGAN ASIMTOT
# Persamaan Asimtot 1: y = (b/a)(x - xc) + yc = (5.0/5.0)(x - 15.0) + 15.0
# Persamaan Asimtot 2: y = -(b/a)(x - xc) + yc = -(5.0/5.0)(x - 15.0) + 15.0
# ----------------------------------------------------------------------------------------------------
# θ (deg)   Perhitungan X (Kanan)         X              Perhitungan Y            Y
# ----------------------------------------------------------------------------------------------------
# -89.9     15.0+5.0*sec(-89.9°)          2879.79        15.0+5.0*tan(-89.9°)     -2849.79
# -79.9     15.0+5.0*sec(-79.9°)          43.51          15.0+5.0*tan(-79.9°)     -13.07
# -69.9     15.0+5.0*sec(-69.9°)          29.55          15.0+5.0*tan(-69.9°)     1.34
# -59.9     15.0+5.0*sec(-59.9°)          24.97          15.0+5.0*tan(-59.9°)     6.37
# -49.9     15.0+5.0*sec(-49.9°)          22.76          15.0+5.0*tan(-49.9°)     9.06
# -39.9     15.0+5.0*sec(-39.9°)          21.52          15.0+5.0*tan(-39.9°)     10.82
# -29.9     15.0+5.0*sec(-29.9°)          20.77          15.0+5.0*tan(-29.9°)     12.12
# -19.9     15.0+5.0*sec(-19.9°)          20.32          15.0+5.0*tan(-19.9°)     13.19
# -9.9      15.0+5.0*sec(-9.9°)           20.08          15.0+5.0*tan(-9.9°)      14.13
# 0.1       15.0+5.0*sec(0.1°)            20.00          15.0+5.0*tan(0.1°)       15.01
# 10.1      15.0+5.0*sec(10.1°)           20.08          15.0+5.0*tan(10.1°)      15.89
# 20.1      15.0+5.0*sec(20.1°)           20.32          15.0+5.0*tan(20.1°)      16.83
# 30.1      15.0+5.0*sec(30.1°)           20.78          15.0+5.0*tan(30.1°)      17.90
# 40.1      15.0+5.0*sec(40.1°)           21.54          15.0+5.0*tan(40.1°)      19.21
# 50.1      15.0+5.0*sec(50.1°)           22.79          15.0+5.0*tan(50.1°)      20.98
# 60.1      15.0+5.0*sec(60.1°)           25.03          15.0+5.0*tan(60.1°)      23.70
# 70.1      15.0+5.0*sec(70.1°)           29.69          15.0+5.0*tan(70.1°)      28.81
# 80.1      15.0+5.0*sec(80.1°)           44.08          15.0+5.0*tan(80.1°)      43.65
# 90.1      15.0+5.0*sec(90.1°)           -2849.79       15.0+5.0*tan(90.1°)      -2849.79
#
# ====================================================================================================
# RESOLUSI TINGGI
# ====================================================================================================
# Delta θ      = 1.0°
# Proses cari jumlah titik: Rentang = 89.9° - (-89.9°) = 179.8°
# Jumlah titik = 179.8° / 1.0° ≈ 180 (per cabang)
# ----------------------------------------------------------------------------------------------------
# PERHITUNGAN TITIK FOKUS
# c = √(a² + b²) = √(5.0² + 5.0²) = √(25.0 + 25.0) = 7.07
# Fokus Kanan (F1) = (xc + c, yc) = (15.0 + 7.07, 15.0) = (22.07, 15.0)
# Fokus Kiri (F2)  = (xc - c, yc) = (15.0 - 7.07, 15.0) = (7.93, 15.0)
# ----------------------------------------------------------------------------------------------------
# PERHITUNGAN ASIMTOT
# Persamaan Asimtot 1: y = (b/a)(x - xc) + yc = (5.0/5.0)(x - 15.0) + 15.0
# Persamaan Asimtot 2: y = -(b/a)(x - xc) + yc = -(5.0/5.0)(x - 15.0) + 15.0
# ----------------------------------------------------------------------------------------------------
# θ (deg)   Perhitungan X (Kanan)         X              Perhitungan Y            Y
# ----------------------------------------------------------------------------------------------------
# -89.9     15.0+5.0*sec(-89.9°)          2879.79        15.0+5.0*tan(-89.9°)     -2849.79
# -88.9     15.0+5.0*sec(-88.9°)          275.45         15.0+5.0*tan(-88.9°)     -245.40
# -87.9     15.0+5.0*sec(-87.9°)          151.45         15.0+5.0*tan(-87.9°)     -121.36
# -86.9     15.0+5.0*sec(-86.9°)          107.46         15.0+5.0*tan(-86.9°)     -77.32
# -85.9     15.0+5.0*sec(-85.9°)          84.93          15.0+5.0*tan(-85.9°)     -54.75
# -84.9     15.0+5.0*sec(-84.9°)          71.25          15.0+5.0*tan(-84.9°)     -41.02
# -83.9     15.0+5.0*sec(-83.9°)          62.05          15.0+5.0*tan(-83.9°)     -31.79
# -82.9     15.0+5.0*sec(-82.9°)          55.45          15.0+5.0*tan(-82.9°)     -25.14
# -81.9     15.0+5.0*sec(-81.9°)          50.49          15.0+5.0*tan(-81.9°)     -20.13
# -80.9     15.0+5.0*sec(-80.9°)          46.61          15.0+5.0*tan(-80.9°)     -16.22
# -79.9     15.0+5.0*sec(-79.9°)          43.51          15.0+5.0*tan(-79.9°)     -13.07
# -78.9     15.0+5.0*sec(-78.9°)          40.97          15.0+5.0*tan(-78.9°)     -10.49
# -77.9     15.0+5.0*sec(-77.9°)          38.85          15.0+5.0*tan(-77.9°)     -8.32
# -76.9     15.0+5.0*sec(-76.9°)          37.06          15.0+5.0*tan(-76.9°)     -6.49
# -75.9     15.0+5.0*sec(-75.9°)          35.52          15.0+5.0*tan(-75.9°)     -4.91
# -74.9     15.0+5.0*sec(-74.9°)          34.19          15.0+5.0*tan(-74.9°)     -3.53
# -73.9     15.0+5.0*sec(-73.9°)          33.03          15.0+5.0*tan(-73.9°)     -2.32
# -72.9     15.0+5.0*sec(-72.9°)          32.00          15.0+5.0*tan(-72.9°)     -1.25
# -71.9     15.0+5.0*sec(-71.9°)          31.09          15.0+5.0*tan(-71.9°)     -0.30
# -70.9     15.0+5.0*sec(-70.9°)          30.28          15.0+5.0*tan(-70.9°)     0.56
# -69.9     15.0+5.0*sec(-69.9°)          29.55          15.0+5.0*tan(-69.9°)     1.34
# -68.9     15.0+5.0*sec(-68.9°)          28.89          15.0+5.0*tan(-68.9°)     2.04
# -5.9      15.0+5.0*sec(-5.9°)           20.03          15.0+5.0*tan(-5.9°)      14.48
# -4.9      15.0+5.0*sec(-4.9°)           20.02          15.0+5.0*tan(-4.9°)      14.57
# -3.9      15.0+5.0*sec(-3.9°)           20.01          15.0+5.0*tan(-3.9°)      14.66
# -2.9      15.0+5.0*sec(-2.9°)           20.01          15.0+5.0*tan(-2.9°)      14.75
# -1.9      15.0+5.0*sec(-1.9°)           20.00          15.0+5.0*tan(-1.9°)      14.83
# -0.9      15.0+5.0*sec(-0.9°)           20.00          15.0+5.0*tan(-0.9°)      14.92
# 0.1       15.0+5.0*sec(0.1°)            20.00          15.0+5.0*tan(0.1°)       15.01
# 1.1       15.0+5.0*sec(1.1°)            20.00          15.0+5.0*tan(1.1°)       15.10
# 2.1       15.0+5.0*sec(2.1°)            20.00          15.0+5.0*tan(2.1°)       15.18
# 3.1       15.0+5.0*sec(3.1°)            20.01          15.0+5.0*tan(3.1°)       15.27
# 4.1       15.0+5.0*sec(4.1°)            20.01          15.0+5.0*tan(4.1°)       15.36
# 5.1       15.0+5.0*sec(5.1°)            20.02          15.0+5.0*tan(5.1°)       15.45
# 6.1       15.0+5.0*sec(6.1°)            20.03          15.0+5.0*tan(6.1°)       15.53
# 7.1       15.0+5.0*sec(7.1°)            20.04          15.0+5.0*tan(7.1°)       15.62
# 8.1       15.0+5.0*sec(8.1°)            20.05          15.0+5.0*tan(8.1°)       15.71
# 9.1       15.0+5.0*sec(9.1°)            20.06          15.0+5.0*tan(9.1°)       15.80
# 10.1      15.0+5.0*sec(10.1°)           20.08          15.0+5.0*tan(10.1°)      15.89
# 11.1      15.0+5.0*sec(11.1°)           20.10          15.0+5.0*tan(11.1°)      15.98
# 12.1      15.0+5.0*sec(12.1°)           20.11          15.0+5.0*tan(12.1°)      16.07
# 13.1      15.0+5.0*sec(13.1°)           20.13          15.0+5.0*tan(13.1°)      16.16
# 14.1      15.0+5.0*sec(14.1°)           20.16          15.0+5.0*tan(14.1°)      16.26
# 15.1      15.0+5.0*sec(15.1°)           20.18          15.0+5.0*tan(15.1°)      16.35
# 16.1      15.0+5.0*sec(16.1°)           20.20          15.0+5.0*tan(16.1°)      16.44
# 17.1      15.0+5.0*sec(17.1°)           20.23          15.0+5.0*tan(17.1°)      16.54
# 18.1      15.0+5.0*sec(18.1°)           20.26          15.0+5.0*tan(18.1°)      16.63
# 19.1      15.0+5.0*sec(19.1°)           20.29          15.0+5.0*tan(19.1°)      16.73
# 20.1      15.0+5.0*sec(20.1°)           20.32          15.0+5.0*tan(20.1°)      16.83
# 21.1      15.0+5.0*sec(21.1°)           20.36          15.0+5.0*tan(21.1°)      16.93
# 22.1      15.0+5.0*sec(22.1°)           20.40          15.0+5.0*tan(22.1°)      17.03
# 23.1      15.0+5.0*sec(23.1°)           20.44          15.0+5.0*tan(23.1°)      17.13
# 24.1      15.0+5.0*sec(24.1°)           20.48          15.0+5.0*tan(24.1°)      17.24
# 25.1      15.0+5.0*sec(25.1°)           20.52          15.0+5.0*tan(25.1°)      17.34
# 26.1      15.0+5.0*sec(26.1°)           20.57          15.0+5.0*tan(26.1°)      17.45
# 27.1      15.0+5.0*sec(27.1°)           20.62          15.0+5.0*tan(27.1°)      17.56
# 28.1      15.0+5.0*sec(28.1°)           20.67          15.0+5.0*tan(28.1°)      17.67
# 29.1      15.0+5.0*sec(29.1°)           20.72          15.0+5.0*tan(29.1°)      17.78
# 30.1      15.0+5.0*sec(30.1°)           20.78          15.0+5.0*tan(30.1°)      17.90
# 31.1      15.0+5.0*sec(31.1°)           20.84          15.0+5.0*tan(31.1°)      18.02
# 32.1      15.0+5.0*sec(32.1°)           20.90          15.0+5.0*tan(32.1°)      18.14
# 33.1      15.0+5.0*sec(33.1°)           20.97          15.0+5.0*tan(33.1°)      18.26
# 34.1      15.0+5.0*sec(34.1°)           21.04          15.0+5.0*tan(34.1°)      18.39
# 35.1      15.0+5.0*sec(35.1°)           21.11          15.0+5.0*tan(35.1°)      18.51
# 36.1      15.0+5.0*sec(36.1°)           21.19          15.0+5.0*tan(36.1°)      18.65
# 37.1      15.0+5.0*sec(37.1°)           21.27          15.0+5.0*tan(37.1°)      18.78
# 38.1      15.0+5.0*sec(38.1°)           21.35          15.0+5.0*tan(38.1°)      18.92
# 39.1      15.0+5.0*sec(39.1°)           21.44          15.0+5.0*tan(39.1°)      19.06
# 40.1      15.0+5.0*sec(40.1°)           21.54          15.0+5.0*tan(40.1°)      19.21
# 41.1      15.0+5.0*sec(41.1°)           21.64          15.0+5.0*tan(41.1°)      19.36
# 42.1      15.0+5.0*sec(42.1°)           21.74          15.0+5.0*tan(42.1°)      19.52
# 43.1      15.0+5.0*sec(43.1°)           21.85          15.0+5.0*tan(43.1°)      19.68
# 44.1      15.0+5.0*sec(44.1°)           21.96          15.0+5.0*tan(44.1°)      19.85
# 45.1      15.0+5.0*sec(45.1°)           22.08          15.0+5.0*tan(45.1°)      20.02
# 46.1      15.0+5.0*sec(46.1°)           22.21          15.0+5.0*tan(46.1°)      20.20
# 47.1      15.0+5.0*sec(47.1°)           22.35          15.0+5.0*tan(47.1°)      20.38
# 48.1      15.0+5.0*sec(48.1°)           22.49          15.0+5.0*tan(48.1°)      20.57
# 49.1      15.0+5.0*sec(49.1°)           22.64          15.0+5.0*tan(49.1°)      20.77
# 50.1      15.0+5.0*sec(50.1°)           22.79          15.0+5.0*tan(50.1°)      20.98
# 51.1      15.0+5.0*sec(51.1°)           22.96          15.0+5.0*tan(51.1°)      21.20
# 52.1      15.0+5.0*sec(52.1°)           23.14          15.0+5.0*tan(52.1°)      21.42
# 53.1      15.0+5.0*sec(53.1°)           23.33          15.0+5.0*tan(53.1°)      21.66
# 54.1      15.0+5.0*sec(54.1°)           23.53          15.0+5.0*tan(54.1°)      21.91
# 55.1      15.0+5.0*sec(55.1°)           23.74          15.0+5.0*tan(55.1°)      22.17
# 56.1      15.0+5.0*sec(56.1°)           23.96          15.0+5.0*tan(56.1°)      22.44
# 57.1      15.0+5.0*sec(57.1°)           24.21          15.0+5.0*tan(57.1°)      22.73
# 58.1      15.0+5.0*sec(58.1°)           24.46          15.0+5.0*tan(58.1°)      23.03
# 59.1      15.0+5.0*sec(59.1°)           24.74          15.0+5.0*tan(59.1°)      23.35
# 60.1      15.0+5.0*sec(60.1°)           25.03          15.0+5.0*tan(60.1°)      23.70
# 61.1      15.0+5.0*sec(61.1°)           25.35          15.0+5.0*tan(61.1°)      24.06
# 62.1      15.0+5.0*sec(62.1°)           25.69          15.0+5.0*tan(62.1°)      24.44
# 63.1      15.0+5.0*sec(63.1°)           26.05          15.0+5.0*tan(63.1°)      24.86
# 64.1      15.0+5.0*sec(64.1°)           26.45          15.0+5.0*tan(64.1°)      25.30
# 65.1      15.0+5.0*sec(65.1°)           26.88          15.0+5.0*tan(65.1°)      25.77
# 66.1      15.0+5.0*sec(66.1°)           27.34          15.0+5.0*tan(66.1°)      26.28
# 67.1      15.0+5.0*sec(67.1°)           27.85          15.0+5.0*tan(67.1°)      26.84
# 68.1      15.0+5.0*sec(68.1°)           28.41          15.0+5.0*tan(68.1°)      27.44
# 69.1      15.0+5.0*sec(69.1°)           29.02          15.0+5.0*tan(69.1°)      28.09
# 70.1      15.0+5.0*sec(70.1°)           29.69          15.0+5.0*tan(70.1°)      28.81
# 71.1      15.0+5.0*sec(71.1°)           30.44          15.0+5.0*tan(71.1°)      29.60
# 72.1      15.0+5.0*sec(72.1°)           31.27          15.0+5.0*tan(72.1°)      30.48
# 73.1      15.0+5.0*sec(73.1°)           32.20          15.0+5.0*tan(73.1°)      31.46
# 74.1      15.0+5.0*sec(74.1°)           33.25          15.0+5.0*tan(74.1°)      32.55
# 75.1      15.0+5.0*sec(75.1°)           34.45          15.0+5.0*tan(75.1°)      33.79
# 76.1      15.0+5.0*sec(76.1°)           35.81          15.0+5.0*tan(76.1°)      35.20
# 77.1      15.0+5.0*sec(77.1°)           37.40          15.0+5.0*tan(77.1°)      36.83
# 78.1      15.0+5.0*sec(78.1°)           39.25          15.0+5.0*tan(78.1°)      38.73
# 79.1      15.0+5.0*sec(79.1°)           41.44          15.0+5.0*tan(79.1°)      40.96
# 80.1      15.0+5.0*sec(80.1°)           44.08          15.0+5.0*tan(80.1°)      43.65
# 81.1      15.0+5.0*sec(81.1°)           47.32          15.0+5.0*tan(81.1°)      46.93
# 82.1      15.0+5.0*sec(82.1°)           51.38          15.0+5.0*tan(82.1°)      51.03
# 83.1      15.0+5.0*sec(83.1°)           56.62          15.0+5.0*tan(83.1°)      56.32
# 84.1      15.0+5.0*sec(84.1°)           63.64          15.0+5.0*tan(84.1°)      63.38
# 85.1      15.0+5.0*sec(85.1°)           73.54          15.0+5.0*tan(85.1°)      73.32
# 86.1      15.0+5.0*sec(86.1°)           88.51          15.0+5.0*tan(86.1°)      88.34
# 87.1      15.0+5.0*sec(87.1°)           113.83         15.0+5.0*tan(87.1°)      113.70
# 88.1      15.0+5.0*sec(88.1°)           165.81         15.0+5.0*tan(88.1°)      165.72
# 89.1      15.0+5.0*sec(89.1°)           333.32         15.0+5.0*tan(89.1°)      333.28
